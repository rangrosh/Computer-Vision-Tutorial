# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)
windowName = 'Live Video Feed'
cv2.namedWindow(windowName)



if cap.isOpened():
    ret, frame = cap.read()
else:
    ret = False

while ret:
    
    ret,frame = cap.read()
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50,150,apertureSize = 3, L2gradient = True)    
    
    lines = cv2.HoughLines(edges , 1, np.pi/180, 200) #image, distance accuracy(rho), angle accuracy(theta), threshold
    #Hough Lines gives it in Polar Coordinates, so we convert to cartesian
    if lines is not None:
        for line in lines:
            rho,theta = line[0]
            a = np.cos(theta)
            b = np.sin(theta)
            x0 = a*rho
            y0 = b*rho
            x1 = int(x0 + 1000*(-b))
            y1 = int(y0 + 1000*(a))
            x2 = int(x0 - 1000*(-b))
            y2 = int(y0 - 1000*(a))
            cv2.line(frame,(x1,y1),(x2,y2),(0,0,255),3)
    
    cv2.imshow(windowName, frame)
    
    if cv2.waitKey(1) == 27:
        break
    
    
cv2.destroyAllWindows()
cap.release()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import random
path = "C:\\Users\\rangr\\Desktop\\Image Processing\\misc\\"
img1p = path + "ruler.512.tiff"
img1 = cv2.imread(img1p,0)


edges = cv2.Canny(img1, 80,150, L2gradient = True)
lines = cv2.HoughLines(edges , 1, np.pi/180, 200) 
if lines is not None:
    for line in lines:
        rho,theta = line[0]
        a = np.cos(theta)
        b = np.sin(theta)
        x0 = a*rho
        y0 = b*rho
        x1 = int(x0 + 1000*(-b))
        y1 = int(y0 + 1000*(a))
        x2 = int(x0 - 1000*(-b))
        y2 = int(y0 - 1000*(a))
        cv2.line(img1,(x1,y1),(x2,y2),(0,0,255),3)
cv2.imshow('hey',img1)
cv2.waitKey(0)
cv2.destroyAllWindows()
    
plt.show()
